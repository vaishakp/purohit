# %%
import reanalyze
import vlconf
vlconf.conf_matplotlib()

from vlconf.verbosity import levels

vlev = levels()
vlev.set_print_verbosity(2)
print(vlev.print_verbosity)
# Out:
# print verbosity has been set to 2 at /home/vaishak.prasad/Projects/Codes/vlconf/vlconf/__init__.py
# 2

# %%
from reanalyze.reanalyze import PERerun

# %%
import htcondor2

# %%
xphm_approved = {
    "S240413p": "",
    "S240414s": "bilby-IMRPhenomXPHM-SpinTaylor-2",
    "S240420dc": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240426s": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240428dr": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240501an": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240505av": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240507p": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240511i": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240512r": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240513ei": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240514x": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240515m": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240519b": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240520cv": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240525p": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240526ak": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S240527en": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240527fv": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240530a": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240531aa": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S240531bp": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240601aj": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240601co": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240612ax": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240615dg": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240615ea": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240618ah": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240621dy": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240621eb": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240621em": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S240622h": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240627by": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240629by": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240630t": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S240703ad": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240705at": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240716b": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240824w": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240825ar": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240830gn": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S240902bq": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240907cg": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240908bs": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240908dg": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240910ci": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240915b": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240915bd": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240916ar": "bilby-IMRPhenomXPHM-SpinTaylor-2",
    "S240919bn": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240920bz": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240920dw": "bilby-IMRPhenomXPHM-SpinTaylor-5",
    "S240921cw": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240922df": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240923ct": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240924a": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240925n": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240930aa": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S240930du": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241002e": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241006k": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241007bw": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241009an": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241009em": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241009l": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241011k": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241101ee": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241102br": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241102cy": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241109bn": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241109p": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241110br": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241111bn": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241113p": "bilby-IMRPhenomXPHM-SpinTaylor-2",
    "S241114bi": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241114y": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241116cq": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241124w": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S241125n": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S241127aj": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241129aa": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241130be": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241130n": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241201ac": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S241210cw": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S241210fu": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241225c": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241225v": "bilby-IMRPhenomXPHM-SpinTaylor-3",
    "S241229ch": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241230bd": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241230ev": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S241231bg": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250101k": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250104v": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250108eo": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250109bi": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250109f": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250114ax": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250116n": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250118az": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250118dp": "bilby-IMRPhenomXPHM-SpinTaylor-2",
    "S250118t": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250119ag": "bilby-IMRPhenomXPHM-SpinTaylor",
    "S250119cv": "bilby-IMRPhenomXPHM-SpinTaylor",
}

# %%
original_work_dir = "/home/pe.o4/GWTC5-HLV/project/working"
project_dir = "/home/vaishak.prasad/Projects/ligo/rean/working_GWTC5"
g5 = PERerun(working_dir=original_work_dir, project_dir=project_dir, apx='IMRPhenomXPHM', approvals=xphm_approved)

# %%
g5.run()
# Out:
# Running find configs
# Running find...
# Running find
